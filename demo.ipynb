# %% [markdown]
# ## Initialisation d'un context Spark Dataframe

# %%
from pyspark import SparkContext, SQLContext
sqlCtx = SQLContext(sc)
sqlCtx

# %% [markdown]
# ## Lecture d'un CSV avec un reader dataframe
# ## Ici le dataset 'titanic'

# %%
df = sqlCtx.load(source="com.databricks.spark.csv", header="true", path = "train.csv")

# %% [markdown]
# ## Découvrir le schéma de mon fichier

# %%
df.printSchema()
# Out:
# root
#  |-- PassengerId: string (nullable = true)
#  |-- Survived: string (nullable = true)
#  |-- Pclass: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Sex: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- SibSp: string (nullable = true)
#  |-- Parch: string (nullable = true)
#  |-- Ticket: string (nullable = true)
#  |-- Fare: string (nullable = true)
#  |-- Cabin: string (nullable = true)
#  |-- Embarked: string (nullable = true)

# %% [markdown]
# ## afficher la 1ere ligne

# %%
df.head()
# Out:
# Row(PassengerId=u'1', Survived=u'0', Pclass=u'3', Name=u'Braund, Mr. Owen Harris', Sex=u'male', Age=u'22', SibSp=u'1', Parch=u'0', Ticket=u'A/5 21171', Fare=u'7.25', Cabin=u'', Embarked=u'S')

# %% [markdown]
# ## Projection

# %%
clean_df = df.select(
    df.PassengerId.alias('id'),
    df.Survived.cast('boolean').alias('survived'),
    df.Pclass.cast('int').alias('pClass'),
    df.Name.alias('name'),
    df.Sex.alias('sex'),
    df.Age.cast('double').alias('age'),
    df.SibSp.cast('int').alias('nb_sibling'),
    df.Parch.cast('int').alias('nb_parent'),
    df.Ticket.alias('ticket'),
    df.Fare.alias('fare'),
    df.Cabin.alias('cabin'),
    df.Embarked.alias('embarked')
)
clean_df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- survived: boolean (nullable = true)
#  |-- pClass: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- age: double (nullable = true)
#  |-- nb_sibling: integer (nullable = true)
#  |-- nb_parent: integer (nullable = true)
#  |-- ticket: string (nullable = true)
#  |-- fare: string (nullable = true)
#  |-- cabin: string (nullable = true)
#  |-- embarked: string (nullable = true)

# %% [markdown]
# ## data transformation

# %% [markdown]
# ### Le but est d'extraire le titre de la personne

# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StringType

extract_title = F.udf(lambda name: name.split(',')[1].strip().split(' ')[0], StringType())

# %%
clean_df = clean_df.withColumn('title', extract_title(clean_df.name))

# %%
clean_df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- survived: boolean (nullable = true)
#  |-- pClass: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- age: double (nullable = true)
#  |-- nb_sibling: integer (nullable = true)
#  |-- nb_parent: integer (nullable = true)
#  |-- ticket: string (nullable = true)
#  |-- fare: string (nullable = true)
#  |-- cabin: string (nullable = true)
#  |-- embarked: string (nullable = true)
#  |-- title: string (nullable = true)

# %%
clean_df.take(1)
# Out:
# [Row(id=u'1', survived=False, pClass=3, name=u'Braund, Mr. Owen Harris', sex=u'male', age=22.0, nb_sibling=1, nb_parent=0, ticket=u'A/5 21171', fare=u'7.25', cabin=u'', embarked=u'S', title=u'Mr.')]

# %% [markdown]
# ## Description des données

# %% [markdown]
# ### Nombre de lignes

# %%
clean_df.count()
# Out:
# 891L

# %% [markdown]
# ### Statistique d'une colonne

# %%
clean_df.select('age').describe().collect()
# Out:
# [Row(summary=u'count', age=714),
#  Row(summary=u'mean', age=29.69911764705882),
#  Row(summary=u'stddev', age=14.516321150817328),
#  Row(summary=u'min', age=0.42),
#  Row(summary=u'max', age=80.0)]

# %% [markdown]
# ## On cherche à remplacer les données d'age manquante

# %% [markdown]
# ### Le titre peut être une bonne indication pour remplacer l'age si absent

# %%
clean_df.filter(clean_df.age.isNull()).groupBy('title').count().collect()
# Out:
# [Row(title=u'Mrs.', count=17),
#  Row(title=u'Miss.', count=36),
#  Row(title=u'Dr.', count=1),
#  Row(title=u'Master.', count=4),
#  Row(title=u'Mr.', count=119)]

# %%
age_stat_by_title = clean_df.groupBy('title').agg(
    clean_df.title,
    F.count(clean_df.age).alias('count_by_age'),
    F.min(clean_df.age).alias('min_age'),
    F.max(clean_df.age).alias('max_age'),
    F.avg(clean_df.age).alias('avg_age')
)
age_stat_by_title.collect()
# Out:
# [Row(title=u'Mme.', count_by_age=1, min_age=24.0, max_age=24.0, avg_age=24.0),
#  Row(title=u'Col.', count_by_age=2, min_age=56.0, max_age=60.0, avg_age=58.0),
#  Row(title=u'Mrs.', count_by_age=108, min_age=14.0, max_age=63.0, avg_age=35.898148148148145),
#  Row(title=u'Miss.', count_by_age=146, min_age=0.75, max_age=63.0, avg_age=21.773972602739725),
#  Row(title=u'Capt.', count_by_age=1, min_age=70.0, max_age=70.0, avg_age=70.0),
#  Row(title=u'Mlle.', count_by_age=2, min_age=24.0, max_age=24.0, avg_age=24.0),
#  Row(title=u'Don.', count_by_age=1, min_age=40.0, max_age=40.0, avg_age=40.0),
#  Row(title=u'Dr.', count_by_age=6, min_age=23.0, max_age=54.0, avg_age=42.0),
#  Row(title=u'Sir.', count_by_age=1, min_age=49.0, max_age=49.0, avg_age=49.0),
#  Row(title=u'Jonkheer.', count_by_age=1, min_age=38.0, max_age=38.0, avg_age=38.0),
#  Row(title=u'Master.', count_by_age=36, min_age=0.42, max_age=12.0, avg_age=4.574166666666667),
#  Row(title=u'Major.', count_by_age=2, min_age=45.0, max_age=52.0, avg_age=48.5),
#  Row(title=u'Mr.', count_by_age=398, min_age=11.0, max_age=80.0, avg_age=32.368090452261306),
#  Row(title=u'the', count_by_age=1, min_age=33.0, max_age=33.0, avg_age=33.0),
#  Row(title=u'Ms.', count_by_age=1, min_age=28.0, max_age=28.0, avg_age=28.0),
#  Row(title=u'Lady.', count_by_age=1, min_age=48.0, max_age=48.0, avg_age=48.0),
#  Row(title=u'Rev.', count_by_age=6, min_age=27.0, max_age=57.0, avg_age=43.166666666666664)]

# %% [markdown]
# ### On insère les données calculer dans le dataframe avec une jointure

# %%
# Bug if join two dataframe from the same source
#clean_df_with_age = age_stat_by_title.join(clean_df, age_stat_by_title.title == clean_df.title, "inner")


sqlCtx.registerDataFrameAsTable(clean_df, "clean_df")
sqlCtx.registerDataFrameAsTable(age_stat_by_title, "age_stat_by_title")
clean_df_with_age = sqlCtx.sql("select * from clean_df join age_stat_by_title on clean_df.title = age_stat_by_title.title")

# Wait for Spark 1.4
#clean_df_with_age = clean_df_with_age.drop(age_stat_by_title.title)

keep = [clean_df[c] for c in clean_df.columns] + [age_stat_by_title[c] for c in age_stat_by_title.columns if c != 'title']
clean_df_with_age = clean_df_with_age.select(*keep)

# %%
clean_df_with_age.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- survived: boolean (nullable = true)
#  |-- pClass: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- age: double (nullable = true)
#  |-- nb_sibling: integer (nullable = true)
#  |-- nb_parent: integer (nullable = true)
#  |-- ticket: string (nullable = true)
#  |-- fare: string (nullable = true)
#  |-- cabin: string (nullable = true)
#  |-- embarked: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- count_by_age: long (nullable = false)
#  |-- min_age: double (nullable = true)
#  |-- max_age: double (nullable = true)
#  |-- avg_age: double (nullable = true)

# %%
clean_df_with_age.count()
# Out:
# 891L

# %% [markdown]
# ### On ajoute une nouvelle colonne contenant l'age si existant ou une estimation

# %%
from pyspark.sql.types import DoubleType
infere_age = F.udf(lambda age,avg_age: avg_age if age == None else age , DoubleType())
final_df = clean_df_with_age.withColumn('age_infered', infere_age(clean_df_with_age.age, clean_df_with_age.avg_age))

# %%
final_df.select(
    "id",
    "survived",
    "pClass",
    "name",
    "sex",
    "nb_sibling",
    "nb_parent",
    "ticket",
    "fare",
    "cabin",
    "embarked",
    "title",
    final_df.age_infered.alias("age")
).repartition(1).saveAsParquetFile("titanic.parquet")

# %% [markdown]
# ##Passage de Spark dataframe vers Spark RDD

# %%
parquet_df = sqlCtx.parquetFile("titanic.parquet")
parquet_df.count()
# Out:
# 891L

# %%
parquet_df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- survived: boolean (nullable = true)
#  |-- pClass: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- nb_sibling: integer (nullable = true)
#  |-- nb_parent: integer (nullable = true)
#  |-- ticket: string (nullable = true)
#  |-- fare: string (nullable = true)
#  |-- cabin: string (nullable = true)
#  |-- embarked: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- age: double (nullable = true)

# %% [markdown]
# Dataframe n'est pas une extension de rdd. Il faut récupérer la référence du RDD

# %%
rdd = parquet_df.rdd
rdd.take(1)
# Out:
# [Row(id=u'370', survived=True, pClass=1, name=u'Aubart, Mme. Leontine Pauline', sex=u'female', nb_sibling=0, nb_parent=0, ticket=u'PC 17477', fare=u'69.3', cabin=u'B35', embarked=u'C', title=u'Mme.', age=24.0)]

# %%
sample = rdd.sample(False, 0.1)
sample
# Out:
# PythonRDD[272] at RDD at PythonRDD.scala:43

# %% [markdown]
# ##Passage de Spark dataframe vers Spark RDD

# %%
sampleDF = sqlCtx.createDataFrame(sample, parquet_df.columns)
sampleDF.printSchema()
sampleDF.count()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- survived: boolean (nullable = true)
#  |-- pClass: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- nb_sibling: long (nullable = true)
#  |-- nb_parent: long (nullable = true)
#  |-- ticket: string (nullable = true)
#  |-- fare: string (nullable = true)
#  |-- cabin: string (nullable = true)
#  |-- embarked: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- age: double (nullable = true)
# 88L

# %%
prdd = sc.parallelize([(1,'a'), (2,'b')])

# %%
df2 = sqlCtx.createDataFrame(prdd, ['id', 'name'])

# %%
df2.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)

# %% [markdown]
# ##Passage de panda vers Spark

# %%
pandasDF = sampleDF.toPandas()

# %%
pandasDF
# Out:
#      id survived  pClass                                               name  \
# 0    16     True       2                   Hewlett, Mrs. (Mary D Kingcome)
# 1   252    False       3         Strom, Mrs. Wilhelm (Elna Matilda Persson)
# 2   363    False       3                    Barbara, Mrs. (Catherine David)
# 3   514     True       1     Rothschild, Mrs. Martin (Elizabeth L. Barrett)
# 4   519     True       2  Angle, Mrs. William A (Florence "Mary" Agnes H...
# 5   559     True       1             Taussig, Mrs. Emil (Tillie Mandelbaum)
# 6   560     True       3       de Messemaeker, Mrs. Guillaume Joseph (Emma)
# 7   582     True       1  Thayer, Mrs. John Borland (Marian Longstreth M...
# 8   592     True       1    Stephenson, Mrs. Walter Bertram (Martha Eustis)
# 9   701     True       1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 10  773    False       2                                  Mack, Mrs. (Mary)
# 11  782     True       1          Dick, Mrs. Albert Adrian (Vera Gillespie)
# 12  800    False       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 13  855    False       2      Carter, Mrs. Ernest Courtenay (Lilian Hughes)
# 14    3     True       3                             Heikkinen, Miss. Laina
# 15  212     True       2                         Cameron, Miss. Clear Annie
# 16  330     True       1                       Hippach, Miss. Jean Gertrude
# 17  397    False       3                                Olsson, Miss. Elina
# 18  437    False       3               Ford, Miss. Doolina Margaret "Daisy"
# 19  475    False       3                        Strandberg, Miss. Ida Sofia
# 20  540     True       1                 Frolicher, Miss. Hedwig Margaritha
# 21  555     True       3                                 Ohman, Miss. Velin
# 22  565    False       3                     Meanwell, Miss. (Marion Ogden)
# 23  692     True       3                                 Karun, Miss. Manca
# 24  743     True       1              Ryerson, Miss. Susan Parker "Suzette"
# 25  751     True       2                                  Wells, Miss. Joan
# 26  126     True       3                       Nicola-Yarred, Master. Elias
# 27  184     True       2                          Becker, Master. Richard F
# 28  262     True       3                  Asplund, Master. Edvin Rojj Felix
# 29  279    False       3                                 Rice, Master. Eric
# ..  ...      ...     ...                                                ...
# 58  488    False       1                            Kent, Mr. Edward Austin
# 59  509    False       3                           Olsen, Mr. Henry Margido
# 60  532    False       3                                  Toufik, Mr. Nakli
# 61  544     True       2                                  Beane, Mr. Edward
# 62  554     True       3                  Leeni, Mr. Fahim ("Philip Zenni")
# 63  561    False       3                           Morrow, Mr. Thomas Rowan
# 64  569    False       3                                Doharr, Mr. Tannous
# 65  575    False       3                       Rush, Mr. Alfred George John
# 66  615    False       3                    Brocklebank, Mr. William Alfred
# 67  617    False       3                          Danbom, Mr. Ernst Gilbert
# 68  651    False       3                                  Mitkoff, Mr. Mito
# 69  656    False       2                          Hickman, Mr. Leonard Mark
# 70  667    False       2                        Butler, Mr. Reginald Fenton
# 71  674     True       2                              Wilhelms, Mr. Charles
# 72  676    False       3                     Edvardsson, Mr. Gustaf Hjalmar
# 73  677    False       3                      Sawyer, Mr. Frederick Charles
# 74  680     True       1                 Cardeza, Mr. Thomas Drake Martinez
# 75  687    False       3                           Panula, Mr. Jaako Arnold
# 76  700    False       3           Humblen, Mr. Adolf Mathias Nicolai Olsen
# 77  729    False       2                    Bryhl, Mr. Kurt Arnold Gottfrid
# 78  783    False       1                             Long, Mr. Milton Clyde
# 79  791    False       3                           Keane, Mr. Andrew "Andy"
# 80  795    False       3                              Dantcheff, Mr. Ristiu
# 81  829     True       3                       McCormack, Mr. Thomas Joseph
# 82  873    False       1                           Carlsson, Mr. Frans Olof
# 83  874    False       3                        Vander Cruyssen, Mr. Victor
# 84  877    False       3                      Gustafsson, Mr. Alfred Ossian
# 85  890     True       1                              Behr, Mr. Karl Howell
# 86  151    False       2                         Bateman, Rev. Robert James
# 87  887    False       2                              Montvila, Rev. Juozas
#
#        sex  nb_sibling  nb_parent             ticket      fare  \
# 0   female           0          0             248706        16
# 1   female           1          1             347054   10.4625
# 2   female           0          1               2691   14.4542
# 3   female           1          0           PC 17603      59.4
# 4   female           1          0             226875        26
# 5   female           1          1             110413     79.65
# 6   female           1          0             345572      17.4
# 7   female           1          1              17421  110.8833
# 8   female           1          0              36947   78.2667
# 9   female           1          0           PC 17757   227.525
# 10  female           0          0        S.O./P.P. 3      10.5
# 11  female           1          0              17474        57
# 12  female           1          1             345773     24.15
# 13  female           1          0             244252        26
# 14  female           0          0   STON/O2. 3101282     7.925
# 15  female           0          0       F.C.C. 13528        21
# 16  female           0          1             111361   57.9792
# 17  female           0          0             350407    7.8542
# 18  female           2          2         W./C. 6608    34.375
# 19  female           0          0               7553    9.8375
# 20  female           0          2              13568      49.5
# 21  female           0          0             347085     7.775
# 22  female           0          0  SOTON/O.Q. 392087      8.05
# 23  female           0          1             349256   13.4167
# 24  female           2          2           PC 17608   262.375
# 25  female           1          1              29103        23
# 26    male           1          0               2651   11.2417
# 27    male           2          1             230136        39
# 28    male           4          2             347077   31.3875
# 29    male           4          1             382652    29.125
# ..     ...         ...        ...                ...       ...
# 58    male           0          0              11771      29.7
# 59    male           0          0             C 4001    22.525
# 60    male           0          0               2641    7.2292
# 61    male           1          0               2908        26
# 62    male           0          0               2620     7.225
# 63    male           0          0             372622      7.75
# 64    male           0          0               2686    7.2292
# 65    male           0          0         A/4. 20589      8.05
# 66    male           0          0             364512      8.05
# 67    male           1          1             347080      14.4
# 68    male           0          0             349221    7.8958
# 69    male           2          0       S.O.C. 14879      73.5
# 70    male           0          0             234686        13
# 71    male           0          0             244270        13
# 72    male           0          0             349912     7.775
# 73    male           0          0             342826      8.05
# 74    male           0          1           PC 17755  512.3292
# 75    male           4          1            3101295   39.6875
# 76    male           0          0             348121      7.65
# 77    male           1          0             236853        26
# 78    male           0          0             113501        30
# 79    male           0          0              12460      7.75
# 80    male           0          0             349203    7.8958
# 81    male           0          0             367228      7.75
# 82    male           0          0                695         5
# 83    male           0          0             345765         9
# 84    male           0          0               7534    9.8458
# 85    male           0          0             111369        30
# 86    male           0          0        S.O.P. 1166    12.525
# 87    male           0          0             211536        13
#
#               cabin embarked    title        age
# 0                          S     Mrs.  55.000000
# 1                G6        S     Mrs.  29.000000
# 2                          C     Mrs.  45.000000
# 3                          C     Mrs.  54.000000
# 4                          S     Mrs.  36.000000
# 5               E67        S     Mrs.  39.000000
# 6                          S     Mrs.  36.000000
# 7               C68        C     Mrs.  39.000000
# 8               D20        C     Mrs.  52.000000
# 9           C62 C64        C     Mrs.  18.000000
# 10              E77        S     Mrs.  57.000000
# 11              B20        S     Mrs.  17.000000
# 12                         S     Mrs.  30.000000
# 13                         S     Mrs.  44.000000
# 14                         S    Miss.  26.000000
# 15                         S    Miss.  35.000000
# 16              B18        C    Miss.  16.000000
# 17                         S    Miss.  31.000000
# 18                         S    Miss.  21.000000
# 19                         S    Miss.  22.000000
# 20              B39        C    Miss.  22.000000
# 21                         S    Miss.  22.000000
# 22                         S    Miss.  21.773973
# 23                         C    Miss.   4.000000
# 24  B57 B59 B63 B66        C    Miss.  21.000000
# 25                         S    Miss.   4.000000
# 26                         C  Master.  12.000000
# 27               F4        S  Master.   1.000000
# 28                         S  Master.   3.000000
# 29                         Q  Master.   7.000000
# ..              ...      ...      ...        ...
# 58              B37        C      Mr.  58.000000
# 59                         S      Mr.  28.000000
# 60                         C      Mr.  32.368090
# 61                         S      Mr.  32.000000
# 62                         C      Mr.  22.000000
# 63                         Q      Mr.  32.368090
# 64                         C      Mr.  32.368090
# 65                         S      Mr.  16.000000
# 66                         S      Mr.  35.000000
# 67                         S      Mr.  34.000000
# 68                         S      Mr.  32.368090
# 69                         S      Mr.  24.000000
# 70                         S      Mr.  25.000000
# 71                         S      Mr.  31.000000
# 72                         S      Mr.  18.000000
# 73                         S      Mr.  24.500000
# 74      B51 B53 B55        C      Mr.  36.000000
# 75                         S      Mr.  14.000000
# 76            F G63        S      Mr.  42.000000
# 77                         S      Mr.  25.000000
# 78               D6        S      Mr.  29.000000
# 79                         Q      Mr.  32.368090
# 80                         S      Mr.  25.000000
# 81                         Q      Mr.  32.368090
# 82      B51 B53 B55        S      Mr.  33.000000
# 83                         S      Mr.  47.000000
# 84                         S      Mr.  20.000000
# 85             C148        C      Mr.  26.000000
# 86                         S     Rev.  51.000000
# 87                         S     Rev.  27.000000
#
# [88 rows x 13 columns]
